# %% [markdown]
# # CareerLens AI
# Notebook 01 – Technology Job Market Data Exploration
#
# ##🎯 Objective
# The objective of this notebook is to explore and understand the Technology Job Market dataset before any preprocessing or analysis is performed.
#
# This exploration focuses on examining the dataset structure, identifying available attributes, assessing data quality, understanding career distribution, and evaluating the suitability of the dataset for developing the CareerLens AI recommendation system.
#
# The insights obtained during this phase will guide subsequent preprocessing, feature engineering, and analytical tasks.
#
# ##📌 Project Background
# CareerLens AI is an AI-powered career intelligence platform designed to bridge the gap between academic education and industry requirements.
#
# The platform analyzes real-world technology job postings to identify market demand, required skills, career trends, and learning pathways for university students, fresh graduates, and entry-level IT professionals.
#
# This notebook represents the first stage of the analytical workflow by exploring the raw dataset before any transformations are applied.

# %% [markdown]
# ## 📊 Dataset Information
#
# | Attribute | Value |
# |-----------|-------|
# | **Dataset** | Technology Job Market Dataset |
# | **Source** | Kaggle |
# | **Original Records** | 1,615,940 |
# | **Features** | 23 |
# | **Primary Language** | English |
# | **Coverage** | Multiple industries and job categories |

# %% [markdown]
# ##🐍 Section 1 — Import Libraries

# %%
import pandas as pd
import numpy as np

# Display all columns
pd.set_option("display.max_columns", None)

# %% [markdown]
# ##📂 Section 2 — Load Dataset

# %%
#Mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Load dataset
file_path = "/content/drive/MyDrive/CareerLensAI/job_descriptions.csv"

df = pd.read_csv(file_path)
df.head()
# Out:
#              Job Id     Experience Qualifications Salary Range    location  \
# 0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K     Douglas
# 1   398454096642776  2 to 12 Years            BCA   $56K-$116K    Ashgabat
# 2   481640072963533  0 to 12 Years            PhD   $61K-$104K       Macao
# 3   688192671473044  4 to 11 Years            PhD    $65K-$91K  Porto-Novo
# 4   117057806156508  1 to 12 Years            MBA    $64K-$87K    Santiago
#
#             Country  latitude  longitude  Work Type  Company Size  \
# 0       Isle of Man   54.2361    -4.5481     Intern         26801
# 1      Turkmenistan   38.9697    59.5563     Intern        100340
# 2  Macao SAR, China   22.1987   113.5439  Temporary         84525
# 3             Benin    9.3077     2.3158  Full-Time        129896
# 4             Chile  -35.6751   -71.5429     Intern         53944
#
#   Job Posting Date Preference      Contact Person                Contact  \
# ...

# %% [markdown]
# ##📏 Section 3 — Dataset Dimensions

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

df.shape
# Out:
# Rows: 1615940
# Columns: 23
# (1615940, 23)

# %% [markdown]
# ##📋 Section 4 — Dataset Structure

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615940 entries, 0 to 1615939
# Data columns (total 23 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Job Id            1615940 non-null  int64
#  1   Experience        1615940 non-null  object
#  2   Qualifications    1615940 non-null  object
#  3   Salary Range      1615940 non-null  object
#  4   location          1615940 non-null  object
#  5   Country           1615940 non-null  object
#  6   latitude          1615940 non-null  float64
#  7   longitude         1615940 non-null  float64
#  8   Work Type         1615940 non-null  object
#  9   Company Size      1615940 non-null  int64
#  10  Job Posting Date  1615940 non-null  object
#  11  Preference        1615940 non-null  object
#  12  Contact Person    1615940 non-null  object
#  13  Contact           1615940 non-null  object
#  14  Job Title         1615940 non-null  object
# ...

# %% [markdown]
# ##🏷️ Section 5 — Column Overview

# %%
df.columns
# Out:
# Index(['Job Id', 'Experience', 'Qualifications', 'Salary Range', 'location',
#        'Country', 'latitude', 'longitude', 'Work Type', 'Company Size',
#        'Job Posting Date', 'Preference', 'Contact Person', 'Contact',
#        'Job Title', 'Role', 'Job Portal', 'Job Description', 'Benefits',
#        'skills', 'Responsibilities', 'Company', 'Company Profile'],
#       dtype='object')

# %% [markdown]
# ##❗ Section 6 — Missing Value Analysis

# %%
missing_values = df.isnull().sum()

missing_values[missing_values > 0]

#The dataset is highly complete. Only the Company Profile attribute contains missing values, while the remaining features have no missing records
# Out:
# Company Profile    5478
# dtype: int64

# %% [markdown]
# ##🔍 Section 7 — Data Types

# %%
df.dtypes.value_counts()
# Out:
# object     19
# int64       2
# float64     2
# Name: count, dtype: int64

# %% [markdown]
# ##💼 Section 8 — Unique Job Roles

# %%
print("Unique Roles:", df["Role"].nunique())
# Out:
# Unique Roles: 376

# %%
df["Role"].value_counts().head(20)
# Out:
# Role
# Interaction Designer         20580
# Network Administrator        17470
# User Interface Designer      14036
# Social Media Manager         13945
# User Experience Designer     13935
# Procurement Analyst          13757
# Social Media Analyst         10659
# Quality Assurance Analyst    10541
# SEO Specialist               10512
# Executive Assistant          10496
# Database Administrator       10482
# Procurement Manager          10407
# Data Analyst                 10406
# Backend Developer            10404
# Demand Planner               10362
# Office Manager               10361
# Customer Success Manager     10308
# Frontend Developer           10308
# Retirement Planner           10305
# Account Executive             7063
# Name: count, dtype: int64

# %% [markdown]
# ##💡 Section 9 — Initial Observations
#
#
#
# *   The dataset contains over 1.6 million job postings, making it suitable for large-scale labor market analysis.
# *   Most attributes are categorical, indicating that text-based analysis and feature engineering will play a significant role.
# * The dataset spans multiple industries, requiring domain-specific filtering before technology-focused analysis.
# * Skills, job descriptions, and responsibilities provide rich textual data for future NLP and recommendation tasks.
# * The dataset contains geographical, educational, and experience-related information that can support deeper market analysis.

# %% [markdown]
# ##🚀 Section 10 — Summary & Next Steps
#
# This notebook explored the structure and characteristics of the Technology Job Market dataset.
#
# The findings confirmed that the dataset is suitable for developing CareerLens AI after appropriate preprocessing.
#
# Next Steps
#
# * Identify technology-related careers.
# * Filter the dataset to technology job postings.
# * Create career domain classifications.
# * Generate a processed dataset for downstream analysis.
